# %%
import pandas as pd
from cabi_functions import load_stations

# %%
df = pd.read_json('https://gbfs.capitalbikeshare.com/gbfs/en/station_information.json')

# %%
df = pd.read_json('https://gbfs.capitalbikeshare.com/gbfs/en/station_information.json')
datalist = df.iloc[0,0]
df = pd.DataFrame(datalist)

# %%
df
# Out:
#     region_id  has_kiosk        lat  eightd_has_key_dispenser station_type  \
# 0          41       True  38.858971                     False      classic
# 1          41       True  38.856425                     False      classic
# 2          41       True  38.861056                     False      classic
# 3          41       True  38.857866                     False      classic
# 4          41       True  38.862303                     False      classic
# ..        ...        ...        ...                       ...          ...
# 657       NaN       True  38.907316                     False      classic
# 658       NaN       True  38.804486                     False      classic
# 659       NaN       True  38.811361                     False      classic
# 660       NaN       True  38.806002                     False      classic
# 661       NaN       True  38.899984                     False      classic
#
#     legacy_id                                        rental_uris  \
# 0           1  {'ios': 'https://dc.lft.to/lastmile_qr_scan', ...
# 1           3  {'ios': 'https://dc.lft.to/lastmile_qr_scan', ...
# 2           4  {'ios': 'https://dc.lft.to/lastmile_qr_scan', ...
# 3           5  {'ios': 'https://dc.lft.to/lastmile_qr_scan', ...
# 4           6  {'ios': 'https://dc.lft.to/lastmile_qr_scan', ...
# ..        ...                                                ...
# 657       708  {'ios': 'https://dc.lft.to/lastmile_qr_scan', ...
# 658       709  {'ios': 'https://dc.lft.to/lastmile_qr_scan', ...
# 659       710  {'ios': 'https://dc.lft.to/lastmile_qr_scan', ...
# 660       711  {'ios': 'https://dc.lft.to/lastmile_qr_scan', ...
# 661       712  {'ios': 'https://dc.lft.to/lastmile_qr_scan', ...
#
#     eightd_station_services short_name  electric_bike_surcharge_waiver  \
# 0                        []      31000                           False
# 1                        []      31002                           False
# 2                        []      31003                           False
# 3                        []      31004                           False
# 4                        []      31005                           False
# ..                      ...        ...                             ...
# 657                      []      31532                           False
# 658                      []      31953                           False
# 659                      []      31954                           False
# 660                      []      31955                           False
# 661                      []      31672                           False
#
#      capacity                                          name station_id  \
# 0          15                           Eads St & 15th St S          1
# 1          17                        Crystal Dr & 20th St S          3
# 2          16                        Crystal Dr & 15th St S          4
# 3          12  Aurora Hills Cmty Ctr / 18th St & S Hayes St          5
# 4          19    Pentagon City Metro / 12th St & S Hayes St          6
# ..        ...                                           ...        ...
# 657        19                          4th & Florida Ave NE        708
# 658        15                   S Pickett St & Shillings St        709
# 659        15                      S Jordan St & Venable St        710
# 660        16                           King St & Peyton St        711
# 661        19                                10th & H St NE        712
#
#            lon                           external_id     rental_methods
# 0   -77.053230  082469cc-1f3f-11e7-bf6b-3863bb334450  [KEY, CREDITCARD]
# 1   -77.049232  08246c35-1f3f-11e7-bf6b-3863bb334450  [KEY, CREDITCARD]
# 2   -77.049417  08246cd5-1f3f-11e7-bf6b-3863bb334450  [KEY, CREDITCARD]
# 3   -77.059490  08246d68-1f3f-11e7-bf6b-3863bb334450  [KEY, CREDITCARD]
# 4   -77.059936  08246df5-1f3f-11e7-bf6b-3863bb334450  [KEY, CREDITCARD]
# ..         ...                                   ...                ...
# 657 -77.000698  21cdfe0d-71ad-4302-a003-3cfc0d355af9  [KEY, CREDITCARD]
# 658 -77.132334  2260574d-dbc6-4416-9f8c-3e1fcc0d9f5b  [KEY, CREDITCARD]
# 659 -77.109975  599f7a69-823e-419a-b70e-8f9666dd4bd1  [KEY, CREDITCARD]
# 660 -77.055911  8321ef62-caa3-45ea-95b2-4a4a97964625  [KEY, CREDITCARD]
# 661 -76.992725  fe755eaf-7f1f-48df-bc40-f51d2af775d1  [KEY, CREDITCARD]
#
# [662 rows x 16 columns]
