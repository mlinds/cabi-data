# %%
import cabi
import pandas as pd

# %% [markdown]
# # Creating trip summary table
# Our goal is to create a table showing the stations in a certain pair of stations
# ## Loading trip data
# First we load the table of all trips, remove any with incomplete data, and convert the datatypes to the most appropriate

# %%
df = cabi.return_trip_datatable()
# clean the NA values out
df = df.dropna()
# convert them to appropriate datatypes
df = df.convert_dtypes()
# Out:
#          1022316 function calls (1017119 primitive calls) in 90.481 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#       140   44.346    0.317   45.811    0.327 {method 'read' of 'pandas._libs.parsers.TextReader' objects}
#       140   35.178    0.251   35.178    0.251 {built-in method pandas._libs.tslib.array_to_datetime}
#       140    4.146    0.030    4.147    0.030 {built-in method io.open}
#      1171    1.115    0.001    1.115    0.001 {built-in method numpy.core._multiarray_umath.implement_array_function}
#       140    1.087    0.008   84.582    0.604 parsers.py:1055(read)
#       140    1.001    0.007    1.001    0.007 {pandas._libs.tslibs.parsing.concat_date_cols}
#       140    0.676    0.005    4.863    0.035 parsers.py:1853(__init__)
#     16763    0.627    0.000    0.627    0.000 {built-in method _codecs.utf_8_decode}
#       140    0.397    0.003   36.697    0.262 parsers.py:3344(_process_date_conversion)
#      1133    0.287    0.000    0.291    0.000 {pandas._libs.lib.infer_dtype}
#       365    0.284    0.001    0.372    0.001 managers.py:1860(_stack_arrays)
#       140    0.170    0.001    0.170    0.001 {method 'close' of '_io.TextIOWrapper' objects}
#         1    0.156    0.156   90.482   90.482 cabi_functions.py:64(return_trip_datatable)
#       140    0.130    0.001   89.807    0.641 parsers.py:447(_read)
#      1345    0.088    0.000    0.088    0.000 {built-in method numpy.empty}
# 225836/225556    0.068    0.000    0.108    0.000 {built-in method builtins.isinstance}
#       421    0.052    0.000    0.052    0.000 {built-in method numpy.arange}
#       140    0.050    0.000    0.050    0.000 {method 'close' of 'pandas._libs.parsers.TextReader' objects}
#     16763    0.034    0.000    0.661    0.000 codecs.py:319(decode)
#     92299    0.028    0.000    0.038    0.000 generic.py:30(_check)
#  1400/560    0.022    0.000    0.109    0.000 base.py:250(__new__)
#       210    0.020    0.000    0.020    0.000 {built-in method pandas._libs.missing.isnaobj}
#     19796    0.018    0.000    0.043    0.000 common.py:1470(is_extension_array_dtype)
#     22799    0.017    0.000    0.033    0.000 common.py:1610(_is_dtype_type)
#    142526    0.016    0.000    0.017    0.000 {built-in method builtins.getattr}
#     22752    0.016    0.000    0.072    0.000 base.py:254(is_dtype)
#     20076    0.014    0.000    0.021    0.000 base.py:411(find)
#     12904    0.014    0.000    0.061    0.000 common.py:537(is_categorical_dtype)
#      6436    0.010    0.000    0.012    0.000 {built-in method numpy.array}
#   700/420    0.010    0.000    0.197    0.000 series.py:238(__init__)
#      1468    0.009    0.000    0.359    0.000 construction.py:423(sanitize_array)
#     67449    0.008    0.000    0.009    0.000 {built-in method builtins.issubclass}
#        70    0.008    0.000    0.008    0.000 {pandas._libs.internals.get_blkno_placements}
#      1837    0.008    0.000    0.046    0.000 blocks.py:2672(get_block_type)
#      6818    0.008    0.000    0.023    0.000 common.py:703(is_integer_dtype)
#     16763    0.008    0.000    0.008    0.000 codecs.py:331(getstate)
#       140    0.008    0.000    0.008    0.000 datetimes.py:87(should_cache)
# 19721/16220    0.007    0.000    0.008    0.000 {built-in method builtins.len}
#      1217    0.006    0.000    0.022    0.000 cast.py:1379(maybe_cast_to_datetime)
#      3608    0.006    0.000    0.022    0.000 common.py:1341(is_bool_dtype)
#      2741    0.006    0.000    0.012    0.000 _dtype.py:321(_name_get)
#       280    0.006    0.000    0.012    0.000 {pandas._libs.lib.clean_index_list}
#      6927    0.006    0.000    0.017    0.000 common.py:201(is_object_dtype)
#       140    0.006    0.000    0.438    0.003 managers.py:1733(_form_blocks)
#      2360    0.005    0.000    0.008    0.000 common.py:231(is_sparse)
#      3935    0.005    0.000    0.015    0.000 dtypes.py:1132(is_dtype)
#      5027    0.004    0.000    0.011    0.000 common.py:1307(is_float_dtype)
#      4286    0.004    0.000    0.016    0.000 dtypes.py:923(is_dtype)
#      1468    0.004    0.000    0.045    0.000 construction.py:554(_try_cast)
#      3600    0.004    0.000    0.008    0.000 {pandas._libs.lib.is_list_like}
#      9165    0.004    0.000    0.006    0.000 common.py:195(<lambda>)
#      5406    0.004    0.000    0.021    0.000 common.py:463(is_period_dtype)
#      1400    0.004    0.000    0.009    0.000 common.py:198(asarray_tuplesafe)
#      5211    0.004    0.000    0.004    0.000 {built-in method _abc._abc_instancecheck}
#      1188    0.004    0.000    0.010    0.000 cast.py:1257(maybe_castable)
#      5055    0.004    0.000    0.020    0.000 common.py:499(is_interval_dtype)
#       789    0.004    0.000    0.016    0.000 blocks.py:127(__init__)
#     13634    0.004    0.000    0.005    0.000 common.py:187(<lambda>)
#       841    0.004    0.000    0.005    0.000 generic.py:188(__init__)
#      3317    0.003    0.000    0.005    0.000 common.py:1769(pandas_dtype)
#      3130    0.003    0.000    0.005    0.000 <frozen importlib._bootstrap>:1033(_handle_fromlist)
#     13634    0.003    0.000    0.003    0.000 common.py:185(classes)
#       789    0.003    0.000    0.009    0.000 blocks.py:269(mgr_locs)
#       140    0.003    0.000   89.811    0.642 parsers.py:533(read_csv)
#      4939    0.003    0.000    0.006    0.000 common.py:1575(get_dtype)
#       630    0.003    0.000    0.007    0.000 cast.py:1617(construct_1d_object_array_from_listlike)
#       789    0.003    0.000    0.043    0.000 blocks.py:2721(make_block)
#     13306    0.003    0.000    0.003    0.000 {built-in method builtins.hasattr}
#      9165    0.003    0.000    0.003    0.000 common.py:190(classes_and_not_datetimelike)
#      1403    0.003    0.000    0.125    0.000 base.py:5836(ensure_index)
#      3710    0.003    0.000    0.005    0.000 common.py:429(is_timedelta64_dtype)
#       210    0.003    0.000    0.013    0.000 datetimes.py:1891(sequence_to_dt64ns)
#      2521    0.003    0.000    0.008    0.000 base.py:5953(maybe_extract_name)
#       910    0.003    0.000    0.008    0.000 generic.py:5467(__setattr__)
# 2675/2535    0.003    0.000    0.043    0.000 {built-in method builtins.all}
#       140    0.003    0.000   36.299    0.259 parsers.py:3302(converter)
#       140    0.003    0.000    0.080    0.001 datetimes.py:143(_maybe_cache)
#       797    0.003    0.000    0.012    0.000 cast.py:1273(maybe_infer_to_datetimelike)
#       140    0.002    0.000   82.516    0.589 parsers.py:2059(read)
#       140    0.002    0.000    0.341    0.002 construction.py:333(_homogenize)
#       383    0.002    0.000    0.002    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#       419    0.002    0.000    0.019    0.000 base.py:4393(equals)
#       560    0.002    0.000    0.011    0.000 base.py:6023(_maybe_cast_data_without_dtype)
#       365    0.002    0.000    0.005    0.000 _asarray.py:293(require)
#        70    0.002    0.000    0.013    0.000 concat.py:92(_get_mgr_concatenation_plan)
#       140    0.002    0.000    0.003    0.000 parsers.py:824(_get_options_with_defaults)
#      2747    0.002    0.000    0.010    0.000 common.py:388(is_datetime64tz_dtype)
#       140    0.002    0.000   35.291    0.252 datetimes.py:609(to_datetime)
#      2027    0.002    0.000    0.015    0.000 common.py:573(is_string_dtype)
#      1470    0.002    0.000    0.005    0.000 common.py:355(is_datetime64_dtype)
#      1135    0.002    0.000    0.003    0.000 base.py:4279(__getitem__)
#      1053    0.002    0.000    1.111    0.001 <__array_function__ internals>:2(concatenate)
#       140    0.002    0.000    0.970    0.007 construction.py:241(init_dict)
#       140    0.002    0.000    4.161    0.030 common.py:491(get_handle)
#      5211    0.002    0.000    0.006    0.000 abc.py:96(__instancecheck__)
#       700    0.002    0.000    0.004    0.000 inference.py:263(is_dict_like)
#       280    0.002    0.000    0.117    0.000 construction.py:632(create_series_with_explicit_dtype)
#      3643    0.002    0.000    0.003    0.000 inference.py:322(is_hashable)
#      3777    0.002    0.000    0.010    0.000 _asarray.py:23(asarray)
#       140    0.002    0.000    0.003    0.000 parsers.py:1509(_maybe_dedup_names)
#      2800    0.002    0.000    0.002    0.000 common.py:912(is_datetime64_any_dtype)
#       140    0.002    0.000    4.864    0.035 parsers.py:1039(_make_engine)
#       840    0.002    0.000    0.004    0.000 series.py:538(name)
#       563    0.002    0.000    0.003    0.000 base.py:425(_simple_new)
#       140    0.002    0.000    0.002    0.000 parsers.py:1272(__init__)
#      2741    0.001    0.000    0.004    0.000 _dtype.py:307(_name_includes_bit_suffix)
#       280    0.001    0.000    0.132    0.000 series.py:372(_init_dict)
#        70    0.001    0.000    0.002    0.000 missing.py:635(<lambda>)
#       843    0.001    0.000    0.002    0.000 base.py:563(_reset_identity)
#       140    0.001    0.000    0.002    0.000 parsers.py:876(_clean_options)
#       140    0.001    0.000    0.005    0.000 range.py:85(__new__)
#       420    0.001    0.000    0.003    0.000 parsers.py:1097(_is_potential_multi_index)
#       140    0.001    0.000    4.872    0.035 parsers.py:780(__init__)
#       420    0.001    0.000    0.022    0.000 managers.py:1577(from_array)
#       141    0.001    0.000    0.972    0.007 frame.py:502(__init__)
#       140    0.001    0.000    0.009    0.000 common.py:210(_get_filepath_or_buffer)
#       419    0.001    0.000    0.012    0.000 missing.py:367(array_equivalent)
#       140    0.001    0.000   35.205    0.251 datetimes.py:267(_convert_listlike_datetimes)
#       700    0.001    0.000    0.003    0.000 series.py:439(_set_axis)
#       350    0.001    0.000    0.009    0.000 datetimes.py:2116(maybe_convert_dtype)
#      1120    0.001    0.000    0.003    0.000 common.py:757(is_signed_integer_dtype)
#       210    0.001    0.000    0.023    0.000 missing.py:244(_isna_string_dtype)
#       280    0.001    0.000    0.001    0.000 parsers.py:394(validate_integer)
#       503    0.001    0.000    0.001    0.000 {pandas._libs.lib.infer_datetimelike_array}
#       141    0.001    0.000    0.002    0.000 generic.py:5411(__finalize__)
#       155    0.001    0.000    0.124    0.001 managers.py:1844(_multi_blockify)
#       210    0.001    0.000    0.045    0.000 missing.py:202(_isna_ndarraylike)
#       140    0.001    0.000    0.011    0.000 series.py:4149(_reduce)
#      2237    0.001    0.000    0.013    0.000 common.py:1551(_is_dtype)
#       841    0.001    0.000    0.001    0.000 flags.py:47(__init__)
#       140    0.001    0.000    0.012    0.000 generic.py:4564(reindex)
#      1608    0.001    0.000    0.005    0.000 construction.py:354(extract_array)
#      2741    0.001    0.000    0.001    0.000 _dtype.py:24(_kind_name)
#       980    0.001    0.000    0.002    0.000 series.py:488(name)
#       140    0.001    0.000    0.445    0.003 managers.py:1690(create_block_manager_from_arrays)
#       140    0.001    0.000    0.004    0.000 parsers.py:1371(_validate_parse_dates_presence)
#       210    0.001    0.000    0.016    0.000 datetimes.py:309(_from_sequence_not_strict)
#      1048    0.001    0.000    0.003    0.000 managers.py:1863(_asarray_compat)
#       140    0.001    0.000   35.182    0.251 datetimes.py:2032(objects_to_datetime64ns)
#        71    0.001    0.000   89.813    1.265 cabi_functions.py:9(_load_files)
#       140    0.001    0.000    0.001    0.000 {built-in method builtins.locals}
#       700    0.001    0.000    0.001    0.000 generic.py:5449(__getattr__)
#      2310    0.001    0.000    0.002    0.000 inference.py:289(<genexpr>)
#      2535    0.001    0.000    0.001    0.000 {pandas._libs.lib.is_scalar}
#       280    0.001    0.000    0.002    0.000 common.py:846(_is_binary_mode)
#      8750    0.001    0.000    0.001    0.000 {method 'get' of 'dict' objects}
#      1120    0.001    0.000    0.002    0.000 common.py:813(is_unsigned_integer_dtype)
#      2516    0.001    0.000    0.009    0.000 common.py:610(<genexpr>)
#       210    0.001    0.000    0.273    0.001 managers.py:1829(_simple_blockify)
#       980    0.001    0.000    0.003    0.000 construction.py:612(is_empty_data)
#       420    0.001    0.000    0.001    0.000 managers.py:1545(__init__)
#       615    0.001    0.000    0.002    0.000 numerictypes.py:359(issubdtype)
#       280    0.001    0.000    0.002    0.000 _ufunc_config.py:32(seterr)
#       140    0.001    0.000    0.004    0.000 nanops.py:243(_get_values)
#       140    0.001    0.000    0.016    0.000 datetimes.py:282(__new__)
#       840    0.001    0.000    0.001    0.000 managers.py:1626(internal_values)
#       140    0.001    0.000    0.017    0.000 datetimes.py:183(_box_as_indexlike)
#      1402    0.001    0.000    0.001    0.000 {built-in method __new__ of type object at 0x00007FFCB45EA650}
#      3643    0.001    0.000    0.001    0.000 {built-in method builtins.hash}
#      1963    0.001    0.000    0.001    0.000 base.py:600(__len__)
#       842    0.001    0.000    0.003    0.000 common.py:1743(validate_all_hashable)
#       560    0.001    0.000    0.004    0.000 base.py:5969(_maybe_cast_with_dtype)
#       173    0.001    0.000    0.024    0.000 missing.py:619(isna_all)
#       419    0.001    0.000    0.002    0.000 missing.py:465(_array_equivalent_object)
#       280    0.001    0.000    0.001    0.000 {built-in method builtins.sorted}
#      1230    0.001    0.000    0.001    0.000 numerictypes.py:285(issubclass_)
#        70    0.001    0.000    0.002    0.000 managers.py:232(_rebuild_blknos_and_blklocs)
#       280    0.001    0.000    0.001    0.000 {built-in method pandas._libs.lib.is_datetime_array}
#       141    0.001    0.000    0.004    0.000 managers.py:126(__init__)
#       365    0.001    0.000    0.001    0.000 _asarray.py:382(<setcomp>)
#       140    0.001    0.000    0.012    0.000 generic.py:10565(_logical_func)
#       140    0.001    0.000    0.001    0.000 parse.py:434(urlsplit)
#       639    0.001    0.000    0.010    0.000 {built-in method builtins.any}
#       280    0.001    0.000    0.001    0.000 _ufunc_config.py:132(geterr)
#       560    0.001    0.000    0.003    0.000 generic.py:340(_validate_dtype)
#       140    0.001    0.000    0.004    0.000 concat.py:451(_select_upcast_cls_from_dtype)
#       140    0.001    0.000    0.005    0.000 base.py:503(to_numpy)
#       140    0.001    0.000    4.162    0.030 parsers.py:1358(_open_handles)
#       141    0.001    0.000    0.003    0.000 managers.py:318(_verify_integrity)
#       140    0.001    0.000    0.002    0.000 parse.py:369(urlparse)
#       140    0.001    0.000    0.002    0.000 range.py:133(_simple_new)
#      1684    0.001    0.000    0.001    0.000 common.py:1762(<genexpr>)
#      1538    0.001    0.000    0.001    0.000 range.py:747(__len__)
#       140    0.001    0.000    0.002    0.000 common.py:438(infer_compression)
#       140    0.001    0.000    0.817    0.006 construction.py:62(arrays_to_mgr)
#       140    0.001    0.000    0.221    0.002 parsers.py:1987(close)
#       351    0.001    0.000    0.002    0.000 managers.py:206(shape)
#       629    0.001    0.000    0.010    0.000 common.py:605(is_excluded_dtype)
#      2886    0.001    0.000    0.001    0.000 {method 'append' of 'list' objects}
#      1221    0.001    0.000    0.001    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#       685    0.001    0.000    0.001    0.000 {method 'format' of 'str' objects}
#       839    0.001    0.000    0.011    0.000 common.py:602(condition)
#       789    0.001    0.000    0.001    0.000 blocks.py:161(_check_ndim)
#      1135    0.001    0.000    0.001    0.000 common.py:129(cast_scalar_indexer)
#       840    0.001    0.000    0.002    0.000 series.py:585(_values)
#       280    0.001    0.000    0.001    0.000 common.py:254(maybe_iterable_to_list)
#      1901    0.001    0.000    0.001    0.000 {pandas._libs.algos.ensure_object}
#       280    0.001    0.000    0.002    0.000 base.py:2134(_is_all_dates)
#      3431    0.001    0.000    0.001    0.000 {method 'pop' of 'dict' objects}
#       140    0.001    0.000    0.001    0.000 base.py:796(__iter__)
#       140    0.001    0.000    0.001    0.000 datetimelike.py:107(_simple_new)
#       210    0.001    0.000    0.001    0.000 {built-in method pandas._libs.tslibs.offsets.to_offset}
#       420    0.001    0.000    0.001    0.000 ntpath.py:289(expanduser)
#       140    0.001    0.000    0.001    0.000 parsers.py:1996(_set_noconvert_columns)
#       419    0.001    0.000    0.001    0.000 {pandas._libs.lib.array_equivalent_object}
#       140    0.001    0.000    0.001    0.000 datetimelike.py:268(__array__)
#       140    0.001    0.000    0.170    0.001 common.py:81(close)
#       140    0.001    0.000   36.697    0.262 parsers.py:1835(_do_date_conversions)
#       840    0.000    0.000    0.001    0.000 parsers.py:1121(<genexpr>)
#       420    0.000    0.000    0.001    0.000 common.py:126(_expand_user)
#       140    0.000    0.000    0.013    0.000 series.py:4337(reindex)
#       280    0.000    0.000    0.002    0.000 common.py:154(stringify_path)
#       211    0.000    0.000    0.001    0.000 datetimes.py:290(_simple_new)
#       140    0.000    0.000    0.001    0.000 common.py:170(all_none)
#       140    0.000    0.000    0.003    0.000 common.py:108(is_url)
#       840    0.000    0.000    0.000    0.000 managers.py:1588(_block)
#       797    0.000    0.000    0.001    0.000 cast.py:1642(construct_1d_ndarray_preserving_na)
#       280    0.000    0.000    0.000    0.000 parse.py:111(_coerce_args)
#       706    0.000    0.000    0.000    0.000 {method 'startswith' of 'str' objects}
#       140    0.000    0.000    0.001    0.000 datetimes.py:551(__array__)
#       280    0.000    0.000    0.025    0.000 concat.py:209(is_na)
#      1330    0.000    0.000    0.052    0.000 base.py:4070(_values)
#      2140    0.000    0.000    0.000    0.000 blocks.py:265(mgr_locs)
#       140    0.000    0.000    0.008    0.000 base.py:4472(identical)
#       140    0.000    0.000    0.171    0.001 parsers.py:1419(close)
#       280    0.000    0.000    0.001    0.000 common.py:954(is_datetime64_ns_dtype)
#       280    0.000    0.000    0.009    0.000 generic.py:4797(<genexpr>)
#       140    0.000    0.000    0.001    0.000 managers.py:689(_consolidate_check)
#       140    0.000    0.000    0.002    0.000 _ufunc_config.py:433(__enter__)
#       140    0.000    0.000    0.024    0.000 missing.py:133(_isna)
#        70    0.000    0.000    0.000    0.000 {built-in method numpy.datetime_data}
#       140    0.000    0.000    0.000    0.000 codecs.py:309(__init__)
#       419    0.000    0.000    0.000    0.000 base.py:532(is_)
#       140    0.000    0.000    0.001    0.000 base.py:1239(name)
#       280    0.000    0.000    0.000    0.000 {built-in method numpy.seterrobj}
#       210    0.000    0.000    0.000    0.000 generic.py:470(_get_axis)
#       421    0.000    0.000    0.000    0.000 blocks.py:2515(_maybe_coerce_values)
#       118    0.000    0.000    0.007    0.000 <__array_function__ internals>:2(putmask)
#       280    0.000    0.000    0.000    0.000 common.py:157(ensure_python_int)
#       140    0.000    0.000    0.001    0.000 managers.py:1699(<listcomp>)
#       140    0.000    0.000    0.001    0.000 generic.py:424(_construct_axes_from_arguments)
#   224/146    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#       210    0.000    0.000    0.001    0.000 datetimelike.py:1787(maybe_infer_freq)
#       280    0.000    0.000    0.000    0.000 common.py:1187(needs_i8_conversion)
#       140    0.000    0.000    0.001    0.000 parsers.py:1545(_make_index)
#       140    0.000    0.000    0.012    0.000 generic.py:10593(any)
#       140    0.000    0.000    0.222    0.002 parsers.py:821(close)
#       140    0.000    0.000    0.006    0.000 nanops.py:442(nanany)
#         4    0.000    0.000    0.001    0.000 concat.py:24(_get_dtype_kinds)
#       140    0.000    0.000    0.027    0.000 generic.py:7416(isna)
#         1    0.000    0.000    0.000    0.000 {built-in method nt.listdir}
#       210    0.000    0.000    0.001    0.000 generic.py:5522(_protect_consolidate)
#         5    0.000    0.000    0.001    0.000 concat.py:536(_combine_concat_plans)
#       140    0.000    0.000    0.001    0.000 typing.py:702(__instancecheck__)
#       210    0.000    0.000    0.002    0.000 {method 'any' of 'numpy.ndarray' objects}
#      1053    0.000    0.000    0.001    0.000 managers.py:208(<genexpr>)
#        26    0.000    0.000    0.000    0.000 numerictypes.py:575(_can_coerce_all)
#       365    0.000    0.000    0.001    0.000 managers.py:1869(_shape_compat)
#       142    0.000    0.000    0.025    0.000 concat.py:491(<genexpr>)
#       210    0.000    0.000    0.001    0.000 generic.py:5538(f)
#       510    0.000    0.000    0.000    0.000 managers.py:320(<genexpr>)
#       138    0.000    0.000    0.000    0.000 blocks.py:324(getitem_block)
#       140    0.000    0.000    0.001    0.000 parsers.py:423(_validate_names)
#       140    0.000    0.000    0.001    0.000 _ufunc_config.py:438(__exit__)
#      1120    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_iterator}
#       141    0.000    0.000    0.000    0.000 managers.py:132(<listcomp>)
#         1    0.000    0.000    0.397    0.397 concat.py:469(get_result)
#       140    0.000    0.000    0.001    0.000 parsers.py:1407(<setcomp>)
#       140    0.000    0.000    0.000    0.000 parsers.py:2021(_set)
#      1205    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_float}
#       770    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         2    0.000    0.000    0.005    0.002 concat.py:425(_get_upcast_classes)
#       140    0.000    0.000    0.003    0.000 parsers.py:1199(_validate_usecols_arg)
#       560    0.000    0.000    0.000    0.000 {built-in method numpy.geterrobj}
#       140    0.000    0.000    0.000    0.000 parsers.py:3786(_refine_defaults_read)
#       140    0.000    0.000    0.001    0.000 typing.py:831(__subclasscheck__)
#       280    0.000    0.000    0.000    0.000 inference.py:96(is_file_like)
#       140    0.000    0.000    0.000    0.000 parsers.py:1249(_validate_parse_dates_arg)
#       280    0.000    0.000    0.002    0.000 parsers.py:1539(_maybe_make_multi_index_columns)
#       141    0.000    0.000    0.000    0.000 flags.py:83(allows_duplicate_labels)
#       210    0.000    0.000    0.001    0.000 generic.py:5534(_consolidate_inplace)
#       140    0.000    0.000    0.000    0.000 managers.py:690(<listcomp>)
#       140    0.000    0.000    0.001    0.000 _dtype.py:34(__str__)
#         1    0.000    0.000   89.929   89.929 concat.py:306(__init__)
#       210    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#       140    0.000    0.000    0.012    0.000 generic.py:10858(any)
#      1053    0.000    0.000    0.000    0.000 multiarray.py:143(concatenate)
#       840    0.000    0.000    0.000    0.000 blocks.py:233(internal_values)
#       140    0.000    0.000    0.222    0.002 parsers.py:1089(__exit__)
#       843    0.000    0.000    0.000    0.000 typing.py:2020(new_type)
#       211    0.000    0.000    0.001    0.000 {built-in method builtins.sum}
#       140    0.000    0.000    0.000    0.000 parsers.py:2136(<dictcomp>)
#       140    0.000    0.000    0.000    0.000 parsers.py:865(_check_file_or_buffer)
#       140    0.000    0.000    0.001    0.000 base.py:618(empty)
#       491    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#       210    0.000    0.000    0.000    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.005    0.003 concat.py:348(_get_empty_dtype_and_na)
#       353    0.000    0.000    0.000    0.000 generic.py:456(_get_axis_number)
#        70    0.000    0.000    0.051    0.001 range.py:152(_data)
#       140    0.000    0.000    0.000    0.000 parsers.py:1423(_has_complex_date_col)
#       140    0.000    0.000    0.027    0.000 series.py:4778(isna)
#       140    0.000    0.000    0.000    0.000 common.py:793(_maybe_memory_map)
#       140    0.000    0.000    0.000    0.000 parsers.py:2134(<listcomp>)
#       140    0.000    0.000    0.000    0.000 missing.py:721(clean_reindex_fill_method)
#       140    0.000    0.000    0.001    0.000 base.py:429(size)
#       140    0.000    0.000    0.000    0.000 <string>:2(__init__)
#       140    0.000    0.000    0.000    0.000 _ufunc_config.py:429(__init__)
#       420    0.000    0.000    0.000    0.000 base.py:623(dtype)
#        69    0.000    0.000    0.001    0.000 concat.py:509(_trim_join_unit)
#       420    0.000    0.000    0.000    0.000 managers.py:1695(<genexpr>)
#       210    0.000    0.000    0.000    0.000 managers.py:975(consolidate)
#       280    0.000    0.000    0.000    0.000 base.py:4485(<genexpr>)
#       210    0.000    0.000    0.001    0.000 common.py:1276(is_string_like_dtype)
#       560    0.000    0.000    0.000    0.000 {method 'endswith' of 'str' objects}
#        70    0.000    0.000    0.000    0.000 parsers.py:1952(<listcomp>)
#       441    0.000    0.000    0.000    0.000 managers.py:210(ndim)
#       140    0.000    0.000    0.000    0.000 {method 'encode' of 'str' objects}
#       210    0.000    0.000    0.002    0.000 _methods.py:53(_any)
#       435    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#       365    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#       140    0.000    0.000    0.000    0.000 generic.py:453(<dictcomp>)
#       140    0.000    0.000    0.000    0.000 nanops.py:330(_na_ok_dtype)
#       369    0.000    0.000    0.000    0.000 blocks.py:343(shape)
#       280    0.000    0.000    0.000    0.000 concat.py:179(__init__)
#       210    0.000    0.000    0.001    0.000 managers.py:681(is_consolidated)
#       700    0.000    0.000    0.000    0.000 {method 'lower' of 'str' objects}
#       140    0.000    0.000    0.000    0.000 parsers.py:3432(_clean_na_values)
#        71    0.000    0.000    0.000    0.000 blocks.py:2240(_maybe_coerce_values)
#       505    0.000    0.000    0.000    0.000 blocks.py:347(dtype)
#       490    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_integer}
#       140    0.000    0.000    0.001    0.000 common.py:403(get_compression_method)
#       140    0.000    0.000    0.001    0.000 nanops.py:199(_maybe_get_mask)
#       210    0.000    0.000    0.000    0.000 {built-in method pandas._libs.tslibs.timezones.maybe_get_tz}
#       140    0.000    0.000    0.000    0.000 codecs.py:260(__init__)
#         1    0.000    0.000    0.001    0.001 _mixins.py:180(<setcomp>)
#       280    0.000    0.000    0.000    0.000 base.py:381(<genexpr>)
#       420    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
#       405    0.000    0.000    0.000    0.000 managers.py:1847(<lambda>)
#       140    0.000    0.000    0.001    0.000 managers.py:991(_consolidate_inplace)
#       140    0.000    0.000    0.000    0.000 common.py:145(validate_header_arg)
#       140    0.000    0.000    0.000    0.000 parsers.py:1125(_evaluate_usecols)
#       420    0.000    0.000    0.000    0.000 parsers.py:1093(_is_index_col)
#       140    0.000    0.000    0.000    0.000 datetimes.py:509(tz)
#        70    0.000    0.000    0.000    0.000 parsers.py:2146(_filter_usecols)
#       425    0.000    0.000    0.000    0.000 base.py:1232(name)
#       280    0.000    0.000    0.000    0.000 common.py:174(<genexpr>)
#         1    0.000    0.000    0.394    0.394 concat.py:35(concatenate_block_managers)
#       140    0.000    0.000    0.000    0.000 concat.py:231(get_reindexed_values)
#       140    0.000    0.000    0.024    0.000 missing.py:50(isna)
#       210    0.000    0.000    0.000    0.000 {method 'view' of 'numpy.ndarray' objects}
#       421    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#       427    0.000    0.000    0.000    0.000 datetimes.py:487(dtype)
#       140    0.000    0.000    0.000    0.000 parsers.py:3353(_isindex)
#        70    0.000    0.000    0.003    0.000 construction.py:405(ensure_wrapped_if_datetimelike)
#       253    0.000    0.000    0.000    0.000 concat.py:487(<genexpr>)
#       140    0.000    0.000    0.000    0.000 concat.py:199(dtype)
#       140    0.000    0.000    0.000    0.000 parsers.py:3971(_validate_skipfooter)
#       173    0.000    0.000    0.001    0.000 {method 'all' of 'numpy.ndarray' objects}
#       420    0.000    0.000    0.000    0.000 {built-in method nt.fspath}
#       420    0.000    0.000    0.000    0.000 datetimes.py:2251(validate_tz_from_dtype)
#       140    0.000    0.000    0.000    0.000 <string>:1(<lambda>)
#       210    0.000    0.000    0.000    0.000 parsers.py:1398(<genexpr>)
#       140    0.000    0.000    0.000    0.000 extension.py:58(fget)
#       107    0.000    0.000    0.000    0.000 common.py:1234(is_numeric_dtype)
#       140    0.000    0.000    0.000    0.000 common.py:198(is_fsspec_url)
#       140    0.000    0.000    0.000    0.000 {built-in method sys.getfilesystemencoding}
#       140    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#   224/146    0.000    0.000    0.000    0.000 abc.py:100(__subclasscheck__)
#       210    0.000    0.000    0.000    0.000 common.py:1304(<lambda>)
#       140    0.000    0.000    0.000    0.000 parsers.py:3299(_make_date_converter)
#       284    0.000    0.000    0.001    0.000 concat.py:139(<genexpr>)
#       210    0.000    0.000    0.000    0.000 datetimes.py:61(tz_to_dtype)
#       140    0.000    0.000    0.000    0.000 frame.py:628(axes)
#       140    0.000    0.000    0.000    0.000 parsers.py:3875(_extract_dialect)
#       140    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#         1    0.000    0.000    0.052    0.052 range.py:731(<listcomp>)
#       280    0.000    0.000    0.000    0.000 concat.py:119(is_nonempty)
#       140    0.000    0.000    0.000    0.000 missing.py:64(clean_fill_method)
#        70    0.000    0.000    0.000    0.000 {method 'find' of 'str' objects}
#       173    0.000    0.000    0.001    0.000 _methods.py:59(_all)
#       281    0.000    0.000    0.000    0.000 concat.py:561(_next_or_none)
#       140    0.000    0.000    0.000    0.000 concat.py:190(needs_filling)
#       351    0.000    0.000    0.000    0.000 generic.py:248(flags)
#       177    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#       297    0.000    0.000    0.000    0.000 blocks.py:147(_maybe_coerce_values)
#        13    0.000    0.000    0.000    0.000 numerictypes.py:599(find_common_type)
#       141    0.000    0.000    0.000    0.000 numeric.py:78(_validate_dtype)
#       140    0.000    0.000    0.000    0.000 function.py:45(__call__)
#       140    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#       281    0.000    0.000    0.000    0.000 typing.py:1333(cast)
#       138    0.000    0.000    0.000    0.000 blocks.py:319(_slice)
#       140    0.000    0.000    0.000    0.000 generic.py:227(attrs)
#       280    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#       210    0.000    0.000    0.000    0.000 flags.py:51(allows_duplicate_labels)
#         4    0.000    0.000    0.348    0.087 concat.py:101(concat_compat)
#       210    0.000    0.000    0.000    0.000 datetimelike.py:1752(validate_inferred_freq)
#         4    0.000    0.000    0.000    0.000 concat.py:130(<listcomp>)
#       138    0.000    0.000    0.000    0.000 blocks.py:114(_simple_new)
#        70    0.000    0.000    0.003    0.000 api.py:221(<genexpr>)
#       141    0.000    0.000    0.000    0.000 managers.py:253(items)
#         2    0.000    0.000    0.000    0.000 concat.py:313(<listcomp>)
#       182    0.000    0.000    0.000    0.000 numerictypes.py:584(<listcomp>)
#         1    0.000    0.000    0.000    0.000 concat.py:375(<listcomp>)
#       140    0.000    0.000    0.000    0.000 {method 'fill' of 'numpy.ndarray' objects}
#       140    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#       140    0.000    0.000    0.000    0.000 nanops.py:174(_get_fill_value)
#       280    0.000    0.000    0.000    0.000 parse.py:100(_noop)
#         1    0.000    0.000    0.000    0.000 api.py:95(_get_distinct_objs)
#        70    0.000    0.000    0.000    0.000 _dtype.py:178(_datetime_metadata_str)
#       210    0.000    0.000    0.000    0.000 datetimes.py:2209(_validate_dt64_dtype)
#       140    0.000    0.000    0.000    0.000 {built-in method builtins.ord}
#        70    0.000    0.000    0.021    0.000 missing.py:638(<lambda>)
#       211    0.000    0.000    0.000    0.000 datetimelike.py:205(_ndarray)
#         1    0.000    0.000    0.013    0.013 concat.py:52(<listcomp>)
#        70    0.000    0.000    0.002    0.000 managers.py:157(blknos)
#       140    0.000    0.000    0.000    0.000 {method 'set_noconvert' of 'pandas._libs.parsers.TextReader' objects}
#       140    0.000    0.000    0.000    0.000 base.py:397(ndim)
#       140    0.000    0.000    0.000    0.000 managers.py:1634(is_consolidated)
#       140    0.000    0.000    0.000    0.000 {method 'index' of 'list' objects}
#        70    0.000    0.000    0.000    0.000 {method 'sort' of 'list' objects}
#        70    0.000    0.000    0.000    0.000 frame.py:645(shape)
#       420    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#        13    0.000    0.000    0.000    0.000 numerictypes.py:651(<listcomp>)
#       118    0.000    0.000    0.000    0.000 multiarray.py:1089(putmask)
#       140    0.000    0.000    0.000    0.000 series.py:422(_constructor)
#        70    0.000    0.000    0.003    0.000 datetimes.py:305(_from_sequence)
#       140    0.000    0.000    0.000    0.000 {method 'reverse' of 'list' objects}
#        71    0.000    0.000    0.000    0.000 _mixins.py:103(shape)
#        71    0.000    0.000    0.000    0.000 generic.py:5442(<genexpr>)
#        71    0.000    0.000    0.000    0.000 _mixins.py:110(ndim)
#       142    0.000    0.000    0.000    0.000 concat.py:494(<genexpr>)
#        70    0.000    0.000    0.000    0.000 managers.py:227(is_single_block)
#         1    0.000    0.000    0.000    0.000 concat.py:390(<listcomp>)
#       140    0.000    0.000    0.000    0.000 parsers.py:1086(__enter__)
#        70    0.000    0.000    0.000    0.000 range.py:207(start)
#       142    0.000    0.000    0.000    0.000 concat.py:329(<genexpr>)
#         1    0.000    0.000   90.482   90.482 {built-in method builtins.exec}
#         1    0.000    0.000    0.003    0.003 concat.py:363(<listcomp>)
#        72    0.000    0.000    0.000    0.000 base.py:1281(_get_names)
#         2    0.000    0.000    0.140    0.070 concat.py:303(_concatenate_join_units)
#         2    0.000    0.000    0.000    0.000 concat.py:70(<listcomp>)
#         1    0.000    0.000    0.000    0.000 base.py:6187(<listcomp>)
#        72    0.000    0.000    0.000    0.000 generic.py:569(ndim)
#        70    0.000    0.000    0.000    0.000 {built-in method from_iterable}
#        70    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_bool}
#         1    0.000    0.000    0.112    0.112 range.py:694(_concat)
#         1    0.000    0.000    0.000    0.000 api.py:91(<listcomp>)
#         1    0.000    0.000    0.000    0.000 concat.py:585(<listcomp>)
#         1    0.000    0.000    0.112    0.112 base.py:4330(append)
#         1    0.000    0.000    0.122    0.122 concat.py:349(_concat_datetime)
#        70    0.000    0.000    0.000    0.000 parse.py:416(_checknetloc)
#         4    0.000    0.000    0.025    0.006 concat.py:476(_is_uniform_join_units)
#         1    0.000    0.000    0.119    0.119 _mixins.py:173(_concat_same_type)
#        70    0.000    0.000    0.000    0.000 managers.py:173(blklocs)
#         1    0.000    0.000    0.000    0.000 concat.py:365(<setcomp>)
#         6    0.000    0.000    0.000    0.000 {method 'clear' of 'dict' objects}
#        70    0.000    0.000    0.000    0.000 range.py:230(stop)
#         1    0.000    0.000   90.325   90.325 concat.py:82(concat)
#        71    0.000    0.000    0.000    0.000 range.py:703(<genexpr>)
#         4    0.000    0.000    0.000    0.000 concat.py:138(<setcomp>)
#         1    0.000    0.000    0.000    0.000 numeric.py:47(__new__)
#        70    0.000    0.000    0.000    0.000 range.py:253(step)
#         1    0.000    0.000    0.000    0.000 base.py:4353(<setcomp>)
#         1    0.000    0.000    0.000    0.000 range.py:709(<listcomp>)
#       140    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#         1    0.000    0.000   90.482   90.482 <string>:1(<module>)
#        56    0.000    0.000    0.000    0.000 _collections_abc.py:409(__subclasshook__)
#         1    0.000    0.000    0.000    0.000 _mixins.py:184(<listcomp>)
#        70    0.000    0.000    0.000    0.000 blocks.py:2236(_can_hold_na)
#         1    0.000    0.000    0.000    0.000 cabi_functions.py:69(<listcomp>)
#         1    0.000    0.000    0.003    0.003 api.py:161(union_indexes)
#         1    0.000    0.000    0.000    0.000 base.py:1250(_validate_names)
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#         1    0.000    0.000    0.000    0.000 base.py:6174(get_unanimous_names)
#         1    0.000    0.000    0.000    0.000 frozen.py:66(__getitem__)
#        71    0.000    0.000    0.000    0.000 common.py:160(<genexpr>)
#         1    0.000    0.000    0.003    0.003 api.py:109(_get_combined_index)
#        10    0.000    0.000    0.000    0.000 concat.py:135(<genexpr>)
#         1    0.000    0.000    0.000    0.000 base.py:826(copy)
#         1    0.000    0.000    0.000    0.000 api.py:253(<setcomp>)
#         1    0.000    0.000    0.119    0.119 datetimelike.py:386(_concat_same_type)
#         1    0.000    0.000    0.000    0.000 datetimelike.py:209(_from_backing_data)
#         1    0.000    0.000    0.112    0.112 concat.py:552(_get_concat_axis)
#         3    0.000    0.000    0.000    0.000 parse.py:85(clear_cache)
#         1    0.000    0.000    0.112    0.112 concat.py:609(_concat_indexes)
#         5    0.000    0.000    0.000    0.000 _collections_abc.py:78(_check_methods)
#         1    0.000    0.000    0.115    0.115 concat.py:537(<listcomp>)
#         1    0.000    0.000    0.000    0.000 base.py:1284(_set_names)
#         2    0.000    0.000    0.000    0.000 base.py:510(_shallow_copy)
#         2    0.000    0.000    0.000    0.000 base.py:6189(<genexpr>)
#         1    0.000    0.000    0.003    0.003 concat.py:542(_get_comb_axis)
#         4    0.000    0.000    0.000    0.000 concat.py:504(<genexpr>)
#         1    0.000    0.000    0.115    0.115 concat.py:535(_get_new_axes)
#         1    0.000    0.000    0.000    0.000 base.py:6188(<listcomp>)
#         1    0.000    0.000    0.000    0.000 base.py:1313(set_names)
#         1    0.000    0.000    0.003    0.003 api.py:65(get_objs_combined_axis)
#        13    0.000    0.000    0.000    0.000 numerictypes.py:652(<listcomp>)
#         1    0.000    0.000    0.000    0.000 numeric.py:107(_shallow_copy)
#         2    0.000    0.000    0.000    0.000 concat.py:501(_is_uniform_reindex)
#         1    0.000    0.000    0.000    0.000 common.py:615(is_dtype_equal)
#         2    0.000    0.000    0.000    0.000 generic.py:476(_get_block_manager_axis)
#         1    0.000    0.000    0.000    0.000 api.py:232(_sanitize_and_check)
#         1    0.000    0.000    0.000    0.000 base.py:1392(rename)
#         6    0.000    0.000    0.000    0.000 _collections_abc.py:283(__subclasshook__)
#         1    0.000    0.000    0.000    0.000 _collections_abc.py:262(__subclasshook__)
#         7    0.000    0.000    0.000    0.000 _collections_abc.py:315(__subclasshook__)
#         2    0.000    0.000    0.000    0.000 blocks.py:308(__len__)
#         1    0.000    0.000    0.000    0.000 common.py:156(not_none)
#         1    0.000    0.000    0.000    0.000 _collections_abc.py:362(__subclasshook__)
#         1    0.000    0.000    0.000    0.000 concat.py:529(_get_result_dim)
#         1    0.000    0.000    0.000    0.000 concat.py:602(_maybe_check_integrity)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 frame.py:482(_constructor)
#         1    0.000    0.000    0.000    0.000 {method 'pop' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 {function FrozenList.__getitem__ at 0x000001883A2BE9D0}

# %% [markdown]
# ## Removing invalid trips
# We have some number of trips where the end station is listed as 0. Obviously these are invalid

# %%
df = df[df.start_station_id > 0]
df = df[df.end_station_id > 0]

# %% [markdown]
# ## Removing trips from removed stations
# We also need to make sure we know the location of the station. Therefore we load the list of stations names. Maybe in the future if I can find a table of the locations of removed stations and we can add them to the visualization
# ### loading our current stations

# %%
# Define which attributes to lookup from airports.csv
cabi_stations = (
    "https://raw.githubusercontent.com/mlinds/cabi-data/main/data/stationLookup.csv"
)
station_names_list = list(pd.read_csv(cabi_stations).short_name)

# %% [markdown]
# ### Selecting only trips involving extant stations
# We rewrite the dataframe to include only stations that exist in our location lookup table

# %%
df = df[df.end_station_id.map(lambda x: x in station_names_list)]
df = df[df.start_station_id.map(lambda x: x in station_names_list)]

# %% [markdown]
# ## Merging based on which stations are involved
# Now to merge based on the same *pairing* of stations (e.g. we do not need to care about which is the origin and which is the destination) to calculate the popularity of that route.

# %%
# create a list of the sorted stations
sorted_stations = [
    sorted([int(x), int(y)]) for x, y in zip(df.start_station_id, df.end_station_id)
]
sorted_stations_combined = [int(str(x) + str(y)) for x, y in sorted_stations]

# we also want to create an integer value for the station pair that is not sorted
unsorted_stations_combined = [
    int(str(x) + str(y)) for x, y in zip(df.start_station_id, df.end_station_id)
]

# %%
# assign the station to a column in the dataframe,and group it by the unique station combo, then return the results to a seperate dataframe
grouped = df.assign(
    sorted_stations=sorted_stations_combined, unsrt=unsorted_stations_combined
).groupby("sorted_stations")

dir_grouped = df.assign(
    sorted_stations=sorted_stations_combined, unsrt=unsorted_stations_combined
).groupby("unsrt")

route_popularity = grouped.count().reset_index()
route_popularity = route_popularity[["sorted_stations", "end_station_id"]]
route_popularity.columns = ["sorted", "popularity"]

# %%
def return_sorted(stationpair: int):
    a, b = sorted((int(str(stationpair)[0:5]), int(str(stationpair)[5:10])))
    return int(str(a) + str(b))

# %%
# directed station pairs
dir_pairs = df.groupby("unsrt").count().reset_index()
dir_pairs = dir_pairs.assign(sorted=[return_sorted(val) for val in dir_pairs.unsrt])

# %%
dir_pairs = dir_pairs.merge(route_popularity, on="sorted")
dir_pairs
# Out:
#              unsrt  started_at  ended_at  start_station_id  end_station_id  \
# 0       3100031000        1956      1956              1956            1956
# 1       3100031002         533       533               533             533
# 2       3100231000         424       424               424             424
# 3       3100031003         539       539               539             539
# 4       3100331000         450       450               450             450
# ...            ...         ...       ...               ...             ...
# 144547  3260932215           1         1                 1               1
# 144548  3260932216           1         1                 1               1
# 144549  3260932220           5         5                 5               5
# 144550  3260932232           5         5                 5               5
# 144551  3260932609         238       238               238             238
#
#         member_casual  sorted_stations      sorted  popularity
# 0                1956             1956  3100031000        1956
# 1                 533              533  3100031002         957
# 2                 424              424  3100031002         957
# 3                 539              539  3100031003         989
# 4                 450              450  3100031003         989
# ...               ...              ...         ...         ...
# 144547              1                1  3221532609           1
# 144548              1                1  3221632609           1
# 144549              5                5  3222032609           5
# 144550              5                5  3223232609           5
# 144551            238              238  3260932609         238
#
# [144552 rows x 9 columns]

# %%
a = [int(str(val)[0:5]) for val in dir_pairs.unsrt]
b = [int(str(val)[5:10]) for val in dir_pairs.unsrt]

dir_pairs = dir_pairs.assign(st=a, en=b)

# %%
dir_pairs
# Out:
#              unsrt  started_at  ended_at  start_station_id  end_station_id  \
# 0       3100031000        1956      1956              1956            1956
# 1       3100031002         533       533               533             533
# 2       3100231000         424       424               424             424
# 3       3100031003         539       539               539             539
# 4       3100331000         450       450               450             450
# ...            ...         ...       ...               ...             ...
# 144547  3260932215           1         1                 1               1
# 144548  3260932216           1         1                 1               1
# 144549  3260932220           5         5                 5               5
# 144550  3260932232           5         5                 5               5
# 144551  3260932609         238       238               238             238
#
#         member_casual  sorted_stations      sorted  popularity     st     en
# 0                1956             1956  3100031000        1956  31000  31000
# 1                 533              533  3100031002         957  31000  31002
# 2                 424              424  3100031002         957  31002  31000
# 3                 539              539  3100031003         989  31000  31003
# 4                 450              450  3100031003         989  31003  31000
# ...               ...              ...         ...         ...    ...    ...
# 144547              1                1  3221532609           1  32609  32215
# 144548              1                1  3221632609           1  32609  32216
# 144549              5                5  3222032609           5  32609  32220
# 144550              5                5  3223232609           5  32609  32232
# 144551            238              238  3260932609         238  32609  32609
#
# [144552 rows x 11 columns]

# %%
undirected_pop = dir_pairs[["st", "en", "popularity"]]
# Out:
#            st     en  popularity
# 72291   31229  31096           1
# 61178   31206  32014           1
# 93687   31275  32049           1
# 133838  31811  31241           1
# 133837  31811  31216           1
# ...       ...    ...         ...
# 124242  31619  31613       66400
# 82191   31258  31249       69514
# 82190   31249  31258       69514
# 81170   31258  31247       78744
# 81169   31247  31258       78744
#
# [144552 rows x 3 columns]

# %%
undirected_pop.to_csv(
    "data/connections_csv.csv", columns=["st", "en", "popularity"], index=False
)

# %% [markdown]
# We will now reassign the start and end, so that we can seperately plot them later
