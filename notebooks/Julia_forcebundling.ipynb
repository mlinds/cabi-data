# %%
using ForceBundle

# %%
pwd()
cd("/workspaces/cabi-data")
pwd()
# Out:
# "/workspaces/cabi-data"

# %%
edges = read_edges_csv("./data/processed/connections_csv.csv";subdivisions=1)
# Out:
# ┌ Warning: thread = 1 warning: only found 3 / 4 columns around data row: 1. Filling remaining columns with `missing`
# └ @ CSV /opt/julia/packages/CSV/0Elut/src/file.jl:577
# ┌ Warning: thread = 1 warning: only found 3 / 4 columns around data row: 2. Filling remaining columns with `missing`
# └ @ CSV /opt/julia/packages/CSV/0Elut/src/file.jl:577
# ┌ Warning: thread = 1 warning: only found 3 / 4 columns around data row: 3. Filling remaining columns with `missing`
# └ @ CSV /opt/julia/packages/CSV/0Elut/src/file.jl:577
# ┌ Warning: thread = 1 warning: only found 3 / 4 columns around data row: 4. Filling remaining columns with `missing`
# └ @ CSV /opt/julia/packages/CSV/0Elut/src/file.jl:577
# ┌ Warning: thread = 1 warning: only found 3 / 4 columns around data row: 5. Filling remaining columns with `missing`
# └ @ CSV /opt/julia/packages/CSV/0Elut/src/file.jl:577
# ┌ Warning: thread = 1 warning: only found 3 / 4 columns around data row: 6. Filling remaining columns with `missing`
# ...
